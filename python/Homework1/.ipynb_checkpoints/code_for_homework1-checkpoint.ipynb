# %%
import numpy as np
import math as mt
from matplotlib import pyplot as plt
import scipy.linalg as sln
# plt.ioff()

# %%
def f(x):
    return np.sin(np.pi*x)*np.sin(np.pi*x)

# %%
a = -2
b = 2

space = b-a

# %%
def shl(nen, nint):
    point = []
    weight = []
    sh = np.zeros((int(nen), int(nint)))
    if(nint == 2):
        point.append(-mt.sqrt(3.0)/3.0)
        point.append(mt.sqrt(3.0)/3.0)
        weight.append(1)
        weight.append(1)
    for l in range(0, int(nint)):
        t = point[l]
        if(nen == 2):
            sh[0][l] = (1.0 - t)/2.0
            sh[1][l] = (1.0 + t)/2.0
            
    return sh

# %%
def we(nint):
    w = []
    if(nint == 2):
        w.append(1)
        w.append(1)
    return w

# %%
k = 1
error = []
nell = []
for i in range(2, 8):
    nel = mt.pow(4, i)
    
    h = space/nel
    nell.append(h)
    X = np.arange(a, b+h, h)
    nen, nint = (k+1), (k+1)
    # print("nel = {}, h = {}, nen = {}, nint = {}".format(nel, h, nen, nint))
    
    M = np.zeros((len(X), len(X)))
    F = np.zeros((len(X)))
    
    for n in range(0, int(nel)):
        # print("For nel = {}...".format(nel))
        Me = np.zeros((int(nen), int(nen)))
        Fe = np.zeros((int(nen)))
        shg = shl(int(nen), int(nint))
        w = we(int(nint))
        for l in range(0, int(nint)):
            xx = 0
            for j in range(0, int(nen)):
                # print("shg(j, l) = {}".format(shg[j][l]))
                # print("X(n+j-1) = {}".format(X[n+j-1]))
                xx += shg[j][l]*X[n+j]
            for k in range(0, int(nen)):
                Fe[k] += f(xx)*shg[k][l]*w[l]*(h/2)
                for r in range(0, int(nen)):
                    Me[r, k] += shg[r][l]*shg[k][l]*w[l]*(h/2)
        for j in range(0, int(nen)):
            F[n+j] += Fe[j]
            for k in range(0, int(nen)):
               M[n+k][n+j] += Me[k][j]
    alpha = sln.solve(M, F)
    plt.figure(figsize=(18, 10))
    plt.plot(X, alpha, 'g--', label='Projeção L2')
    XX = np.arange(a, b+0.0001, 0.0001)
    plt.plot(XX, f(XX), label='Exata')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    title = 'Comparação solução exata com projeção L2 para {} elementos com {} pontos de integração e h {}'.format(nel, nint, h)
    file_to_save = 'nel_{}_nint_{}_h_{}.png'.format(nel, nint, h)
    plt.title(title)
    plt.savefig(file_to_save)
    
    erul2 = 0
    
    for n in range(0, int(nel)):
        eru = 0
        shg = shl(int(nen), int(nint))
        w = we(int(nint))
        for l in range(0, int(nint)):
            uh = 0.0
            xx = 0.0
            for k in range(0, int(nen)):
                uh += shg[k][l]*alpha[n+k]
                xx += shg[k][l]*X[n+k]
            eru += ((f(xx)-uh)**2)*w[l]*(h/2)
        erul2 += eru
    erul2 = mt.sqrt(erul2)
    error.append(erul2)

# %%
slope, intercept = np.polyfit(nell, error, 1)
print("Slope:", str(slope))

error = error[::-1]
error = np.array(error)
nell = np.array(nell)
plt.figure(figsize=(18, 10))
plt.loglog(nell, error)
plt.xlabel('nel')
plt.ylabel('erro')
title = 'Erro em função do espaçamento'
file_to_save = 'error_linear.png'
plt.title(title)
plt.legend()
plt.savefig(file_to_save)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope: 0.5374979925610285

# %%
print(mt.sin(PI))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(mt.sin(PI))
#
# NameError: name 'PI' is not defined

# %%
values_x = []
values_alpha = []

with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_xl.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_x.append(value)

with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_alphas.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_alpha.append(value)

# %%
plt.figure(figsize=(18, 10))
plt.plot(values_x, values_alpha, 'r--', label='Projeção L2')
XX = np.arange(-2, 2+0.0001, 0.0001)
plt.plot(XX, f(XX), 'b', label='Exata')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
title = 'Comparação solução exata com projeção L2 para {} elementos com {} pontos de integração e h {}'.format(1024, 2, (-2-2)/(1024))
file_to_save = 'nel_{}_nint_{}_h_{}.png'.format(1024, 2, (-2-2)/(1024))
plt.title(title)
plt.savefig(file_to_save)
plt.show()

# %%
values_x = []
values_alpha = []
nel = 16
with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_xl_16.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_x.append(value)

with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_alphas_16.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_alpha.append(value)

plt.figure(figsize=(18, 10))
plt.plot(values_x, values_alpha, 'r--', label='Projeção L2')
XX = np.arange(-2, 2+0.0001, 0.0001)
plt.plot(XX, f(XX), 'b', label='Exata')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
title = 'Comparação solução exata com projeção L2 para {} elementos com {} pontos de integração e h {}'.format(nel, 2, (-2-2)/(nel))
file_to_save = '/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/nel_{}_nint_{}_h_{}.png'.format(nel, 2, (-2-2)/(nel))
plt.title(title)
plt.savefig(file_to_save)
;
# plt.show()
# Out:
# ''

# %%
values_x = []
values_alpha = []
nel = 64
with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_xl_64.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_x.append(value)

with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_alphas_64.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_alpha.append(value)

plt.figure(figsize=(18, 10))
plt.plot(values_x, values_alpha, 'r--', label='Projeção L2')
XX = np.arange(-2, 2+0.0001, 0.0001)
plt.plot(XX, f(XX), 'b', label='Exata')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
title = 'Comparação solução exata com projeção L2 para {} elementos com {} pontos de integração e h {}'.format(nel, 2, (-2-2)/(nel))
file_to_save = '/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/nel_{}_nint_{}_h_{}.png'.format(nel, 2, (-2-2)/(nel))
plt.title(title)
plt.savefig(file_to_save)
;
# plt.show()
# Out:
# ''

# %%
values_x = []
values_alpha = []
nel = 256
with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_xl_256.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_x.append(value)

with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_alphas_256.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_alpha.append(value)

plt.figure(figsize=(18, 10))
plt.plot(values_x, values_alpha, 'r--', label='Projeção L2')
XX = np.arange(-2, 2+0.0001, 0.0001)
plt.plot(XX, f(XX), 'b', label='Exata')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
title = 'Comparação solução exata com projeção L2 para {} elementos com {} pontos de integração e h {}'.format(nel, 2, (-2-2)/(nel))
file_to_save = '/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/nel_{}_nint_{}_h_{}.png'.format(nel, 2, (-2-2)/(nel))
plt.title(title)
plt.savefig(file_to_save)
;
# plt.show()
# Out:
# ''

# %%
values_x = []
values_alpha = []
nel = 1024
with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_xl_1024.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_x.append(value)

with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_alphas_1024.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_alpha.append(value)

plt.figure(figsize=(18, 10))
plt.plot(values_x, values_alpha, 'r--', label='Projeção L2')
XX = np.arange(-2, 2+0.0001, 0.0001)
plt.plot(XX, f(XX), 'b', label='Exata')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
title = 'Comparação solução exata com projeção L2 para {} elementos com {} pontos de integração e h {}'.format(nel, 2, (-2-2)/(nel))
file_to_save = '/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/nel_{}_nint_{}_h_{}.png'.format(nel, 2, (-2-2)/(nel))
plt.title(title)
plt.savefig(file_to_save)
;
# plt.show()
# Out:
# ''

# %%
values_x = []
values_alpha = []
nel = 4096
with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_xl_4096.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_x.append(value)

with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/resultados_alphas_4096.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        values_alpha.append(value)

plt.figure(figsize=(18, 10))
plt.plot(values_x, values_alpha, 'r--', label='Projeção L2')
XX = np.arange(-2, 2+0.0001, 0.0001)
plt.plot(XX, f(XX), 'b', label='Exata')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
title = 'Comparação solução exata com projeção L2 para {} elementos com {} pontos de integração e h {}'.format(nel, 2, (-2-2)/(nel))
file_to_save = '/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/nel_{}_nint_{}_h_{}.png'.format(nel, 2, (-2-2)/(nel))
plt.title(title)
plt.savefig(file_to_save)
;
# plt.show()
# Out:
# ''

# %%
h_s = []
error = []
with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/h_s.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        h_s.append(value)

with open('/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/erros.dat', 'r') as file:
    for line in file:
        value = float(line.strip())
        error.append(value)



error = np.log(error)
h_s = -np.log(h_s)
print(h_s)

print(error)
slope, intercept = np.polyfit(h_s, error, 1)
print("Slope:", str(slope))
# h_s = np.array(h_s)
# error = np.array(error)

plt.figure(figsize=(18, 10))
plt.plot(h_s, error)
plt.xlabel('-log(h)')
plt.ylabel('log(error)')
plt.legend()
plt.grid(True)
title = 'Comparação erros'
file_to_save = '/home/joao-oliveira/Documents/Repositories/Finite-Elements-Method-219016/julia/homework1/comparacao_erros.png'
plt.title(title)
plt.savefig(file_to_save)
;
# plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [1.38629436 2.77258872 4.15888308 5.54517744 6.93147181]
# [ -2.15419343  -4.99314597  -7.76353932 -10.53442886 -13.30624465]
# Slope: -2.0086199658848116
# ''
